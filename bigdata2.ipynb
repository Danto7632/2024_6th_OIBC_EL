# %%
import requests

# 날짜 설정
date_da = '2024-11-07'
date_rt_rc = '2024-11-07'

# smp_da 데이터 요청
smp_da = requests.get(
    f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date_da}',
    headers={
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJINXI3TXZGZm9IUGZnaEd0UGRBMk1pIiwiaWF0IjoxNzMwODA2NzcyLCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.lWotiXYOoP-tEQ5W5B43dpLiMoRSj8l8zUgxrCjOLos'
    }
).json()

# smp_rt_rc 데이터 요청
smp_rt_rc = requests.get(
    f'https://research-api.solarkim.com/data/cmpt-2024/smp-rt-rc/{date_rt_rc}',
    headers={
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJINXI3TXZGZm9IUGZnaEd0UGRBMk1pIiwiaWF0IjoxNzMwODA2NzcyLCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.lWotiXYOoP-tEQ5W5B43dpLiMoRSj8l8zUgxrCjOLos'
    }
).json()

# smp_da 데이터를 {ts: smp_da} 형태로 변환
smp_da_dict = {entry['ts']: entry['smp_da'] for entry in smp_da}

# ts가 같고 smp_da와 smp_rt가 일치하는 경우 필터링
filtered_data = [
    {'ts': entry['ts'], 'smp_rt': entry['smp_rt']}
    for entry in smp_rt_rc
    if entry['ts'] in smp_da_dict and entry['smp_rt'] == smp_da_dict[entry['ts']]
]

print(filtered_data)
# Out:
# [{'ts': 1730908800, 'smp_rt': 103.65}, {'ts': 1730912400, 'smp_rt': 89.39}, {'ts': 1730916000, 'smp_rt': 89.39}, {'ts': 1730919600, 'smp_rt': 89.48}, {'ts': 1730923200, 'smp_rt': 89.48}, {'ts': 1730926800, 'smp_rt': 102.16}, {'ts': 1730930400, 'smp_rt': 114.48}, {'ts': 1730934000, 'smp_rt': 107.74}, {'ts': 1730937600, 'smp_rt': 117.84}, {'ts': 1730941200, 'smp_rt': 136.21}, {'ts': 1730948400, 'smp_rt': 136.87}, {'ts': 1730952000, 'smp_rt': 116.13}, {'ts': 1730955600, 'smp_rt': 116.84}, {'ts': 1730959200, 'smp_rt': 116.84}, {'ts': 1730962800, 'smp_rt': 116.84}, {'ts': 1730966400, 'smp_rt': 151.02}, {'ts': 1730973600, 'smp_rt': 117.44}, {'ts': 1730980800, 'smp_rt': 114.94}, {'ts': 1730984400, 'smp_rt': 107.66}, {'ts': 1730988000, 'smp_rt': 111.71}, {'ts': 1730991600, 'smp_rt': 104.64}]

# %%
import requests

date = '2024-10-23'
weather_forecast = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/weather-forecast/{date}', headers={
                            'Authorization': f'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJINXI3TXZGZm9IUGZnaEd0UGRBMk1pIiwiaWF0IjoxNzMwODA2NzcyLCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.lWotiXYOoP-tEQ5W5B43dpLiMoRSj8l8zUgxrCjOLos'
                        }).json()
print(weather_forecast)
# Out:
# {'weather_forecast_1': [{'base_ts': 1729648800, 'ts': 1729695600, 'temp': 16.6667, 'real_feel_temp': 13.8889, 'wet_bulb_temp': 13.8889, 'dew_point': 11.1111, 'wind_spd': 20.4387, 'wind_dir': 11.0, 'wind_gust_spd': 42.6476, 'rel_hum': 71.0, 'vis': 16.0934, 'ceiling': 9144.0, 'uv_idx': 0.0, 'precip_prob': 0.0, 'rain_prob': 0.0, 'snow_prob': 0.0, 'ice_prob': 0.0, 'total_liq': 0.0, 'rain': 0.0, 'snow': 0.0, 'ice': 0.0, 'cld_cvr': 2.0, 'location': 'Ilgwa-ri'}, {'base_ts': 1729648800, 'ts': 1729699200, 'temp': 16.6667, 'real_feel_temp': 13.8889, 'wet_bulb_temp': 13.3333, 'dew_point': 11.1111, 'wind_spd': 20.4387, 'wind_dir': 11.0, 'wind_gust_spd': 42.6476, 'rel_hum': 72.0, 'vis': 16.0934, 'ceiling': 9144.0, 'uv_idx': 0.0, 'precip_prob': 0.0, 'rain_prob': 0.0, 'snow_prob': 0.0, 'ice_prob': 0.0, 'total_liq': 0.0, 'rain': 0.0, 'snow': 0.0, 'ice': 0.0, 'cld_cvr': 2.0, 'location': 'Ilgwa-ri'}, {'base_ts': 1729648800, 'ts': 1729702800, 'temp': 16.1111, 'real_feel_temp': 13.8889, 'wet_bulb_temp':
# ...

# %%
import numpy as np

def calculate_measure(actual, forecast):
    actual = np.array(actual)
    forecast = np.array(forecast)

    positive_index = actual > 0
    negative_index = actual <= 0

    # actual handles values ​​between 0 and -1
    actual[(actual <= 0) & (actual > -1)] = -1

    # Number of positive and negative prices
    n1 = np.sum(positive_index) + 1e-7
    n2 = np.sum(negative_index) + 1e-7

    # e1: Positive price prediction error rate
    e1 = (
        np.sum(
            np.abs(actual[positive_index] - forecast[positive_index])
            / np.abs(actual[positive_index])
        )
        / n1
    )

    # e2: Negative price prediction error rate
    e2 = (
        np.sum(
            np.abs(actual[negative_index] - forecast[negative_index])
            / np.abs(actual[negative_index])
        )
        / n2
    )

    TP = np.sum((forecast > 0) & (actual > 0))
    TN = np.sum((forecast <= 0) & (actual <= 0))
    FP = np.sum((forecast > 0) & (actual <= 0))
    FN = np.sum((forecast <= 0) & (actual > 0))

    # Accuracy Calculation
    Accuracy = (TP + TN) / (TP + TN + FP + FN)
    print(f'Accuracy: {Accuracy}')
    print(f'e1: {e1}, e2: {e2}')

    e_F = 0.2 * e1 + 0.8 * e2 - (Accuracy - 0.95)

    return e_F

API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJINXI3TXZGZm9IUGZnaEd0UGRBMk1pIiwiaWF0IjoxNzMwODA2NzcyLCJleHAiOjE3MzE1OTY0MDAsInR5cGUiOiJhcGlfa2V5In0.lWotiXYOoP-tEQ5W5B43dpLiMoRSj8l8zUgxrCjOLos"

# 실측 데이터 가져오기
import requests

date = '2024-11-03'
test3 = requests.get(f'https://research-api.solarkim.com/data/cmpt-2024/smp-da/{date}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()
# smp_da 값만 추출
smp_data = [entry['smp_da'] for entry in test3]

# 예측 데이터 생성 (1부터 24까지의 숫자를 가진 문자열)
#forecast_data = [0.0] * 24

forecast_data = [str(i) for i in range(101, 125)]

# 문자열을 숫자형 배열로 변환
forecast_data = np.array(forecast_data, dtype=float)

# 오차 계산
e_F = calculate_measure(smp_data, forecast_data)
print(f'e_F: {e_F}')
# Out:
# Accuracy: 0.9583333333333334
# e1: 0.12180549169234284, e2: 113.99998860000113
# e_F: 91.21601864500605
